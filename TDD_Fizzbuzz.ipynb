# %% [markdown]
# <a href="https://colab.research.google.com/github/rickvelloso/Learning-IA/blob/main/TDD_Fizzbuzz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 TDD na Prática: A "Abordagem 1" com FizzBuzz
#
# Este notebook demonstra o ciclo **Red-Green-Refactor**, seguindo a "Abordagem 1": vamos intencionalmente escrever o código *mínimo e mais simples* (mesmo que pareça "bobo") para ilustrar como o TDD nos força a refatorar e generalizar.
#
# **Regras do FizzBuzz:**
# 1.  Divisível por 3: "Fizz"
# 2.  Divisível por 5: "Buzz"
# 3.  Divisível por 3 e 5: "FizzBuzz"
# 4.  Outros: O próprio número (como string)

# %%
# !pip install -q pytest

# %%writefile fizzbuzz.py
def fizzbuzz(num):
    pass
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %% [markdown]
# ## 🔄 Ciclo 1: A Regra Padrão (e o "Fake it")
#
# ### 🔴 RED
# Começamos com o primeiro teste: `fizzbuzz(1)` deve retornar `"1"`.

# %%
# %%writefile test_fizzbuzz.py
from fizzbuzz import fizzbuzz

def test_retorna_1_para_1():
    assert fizzbuzz(1) == "1"
# Out:
# Overwriting test_fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# ______________________ ERROR collecting test_fizzbuzz.py _______________________
# ImportError while importing test module '/content/test_fizzbuzz.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /usr/lib/python3.12/importlib/__init__.py:90: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# test_fizzbuzz.py:1: in <module>
#     from fizzbuzz import fizzbuzz
# E   ModuleNotFoundError: No module named 'fizzbuzz'
# =========================== short test summary info ============================
# ...

# %% [markdown]
# *(**Resultado Esperado:** Falha. `assert None == '1'`)*
#
# ### 🟢 GREEN (O Passo "Bobo" Intencional)
# O teste falhou.
#
# > **(O que você vai dizer - Abordagem 1):** "Ok, o TDD purista e o princípio 'Fake it, till you make it' dizem que eu devo escrever o código *mínimo e mais simples possível* para o teste passar. Neste caso, o código mais simples é 'hardcodar' o retorno. Vamos fazer isso."

# %%
# %%writefile fizzbuzz.py
def fizzbuzz(num):
    return "1"
# Out:
# Writing fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 1 item
#
# test_fizzbuzz.py .                                                       [100%]
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# ## 🔄 Ciclo 2: Forçando a Refatoração
#
# ### 🔴 RED
# O código está verde, mas sabemos que está errado. Como o TDD nos ajuda a corrigir isso? **Escrevendo outro teste** que expõe a falha.

# %%
# %%writefile test_fizzbuzz.py
from fizzbuzz import fizzbuzz

def test_retorna_1_para_1():
    assert fizzbuzz(1) == "1"

def test_retorna_2_para_2():
    assert fizzbuzz(2) == "2"
# Out:
# Overwriting test_fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 2 items
#
# test_fizzbuzz.py .F                                                      [100%]
#
# =================================== FAILURES ===================================
# ____________________________ test_retorna_2_para_2 _____________________________
#
#     def test_retorna_2_para_2():
# >       assert fizzbuzz(2) == "2"
# E       AssertionError: assert '1' == '2'
# E
# E         - 2
# E         + 1
#
# test_fizzbuzz.py:7: AssertionError
# =========================== short test summary info ============================
# FAILED test_fizzbuzz.py::test_retorna_2_para_2 - AssertionError: assert '1' == '2'
# ========================= 1 failed, 1 passed in 0.08s ==========================

# %% [markdown]
# *(**Resultado Esperado:** Falha no `test_retorna_2_para_2`. `assert '1' == '2'`)*
#
# ### 🟢 GREEN + 🔵 REFACTOR
# > **(O que você vai dizer):** "Vejam! O `test_2` falhou e provou que nossa solução 'boba' não funciona. O TDD agora está nos *forçando* a 'make it', ou seja, a generalizar e refatorar para a lógica correta."

# %%
# %%writefile fizzbuzz.py
def fizzbuzz(num):
    return str(num)
# Out:
# Overwriting fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 2 items
#
# test_fizzbuzz.py ..                                                      [100%]
#
# ============================== 2 passed in 0.01s ===============================

# %% [markdown]
# *(**Resultado Esperado:** 2 testes passando).*
#
# ## 🔄 Ciclo 3: Regra "Fizz"
#
# Agora que o caso padrão funciona, vamos adicionar a primeira regra de negócio.
#
# ### 🔴 RED

# %%
# %%writefile test_fizzbuzz.py
from fizzbuzz import fizzbuzz

def test_retorna_1_para_1():
    assert fizzbuzz(1) == "1"
def test_retorna_2_para_2():
    assert fizzbuzz(2) == "2"

def test_retorna_Fizz_para_3():
    assert fizzbuzz(3) == "Fizz"
# Out:
# Overwriting test_fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 3 items
#
# test_fizzbuzz.py ..F                                                     [100%]
#
# =================================== FAILURES ===================================
# ___________________________ test_retorna_Fizz_para_3 ___________________________
#
#     def test_retorna_Fizz_para_3():
# >       assert fizzbuzz(3) == "Fizz"
# E       AssertionError: assert '3' == 'Fizz'
# E
# E         - Fizz
# E         + 3
#
# test_fizzbuzz.py:9: AssertionError
# =========================== short test summary info ============================
# FAILED test_fizzbuzz.py::test_retorna_Fizz_para_3 - AssertionError: assert '3' == 'Fizz'
# ========================= 1 failed, 2 passed in 0.13s ==========================

# %% [markdown]
# *(**Resultado Esperado:** Falha. `assert '3' == 'Fizz'`)*
#
# ### 🟢 GREEN

# %%
# %%writefile fizzbuzz.py
def fizzbuzz(num):
    if num % 3 == 0:
        return "Fizz"

    return str(num)
# Out:
# Overwriting fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 5 items
#
# test_fizzbuzz.py ...FF                                                   [100%]
#
# =================================== FAILURES ===================================
# ___________________________ test_retorna_Buzz_para_5 ___________________________
#
# >   def test_retorna_Buzz_para_5(): assert fizzbuzz(5) == "Buzz"
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E   AssertionError: assert '5' == 'Buzz'
# E
# E     - Buzz
# E     + 5
#
# test_fizzbuzz.py:7: AssertionError
# ________________________ test_retorna_FizzBuzz_para_15 _________________________
#
#     def test_retorna_FizzBuzz_para_15():
# >       assert fizzbuzz(15) == "FizzBuzz"
# E       AssertionError: assert 'Fizz' == 'FizzBuzz'
# E
# E         - FizzBuzz
# ...

# %% [markdown]
# ## 🔄 Ciclo 4: Regra "Buzz"
#
# ### 🔴 RED

# %%
# %%writefile test_fizzbuzz.py
from fizzbuzz import fizzbuzz

def test_retorna_1_para_1(): assert fizzbuzz(1) == "1"
def test_retorna_2_para_2(): assert fizzbuzz(2) == "2"
def test_retorna_Fizz_para_3(): assert fizzbuzz(3) == "Fizz"

def test_retorna_Buzz_para_5():
    assert fizzbuzz(5) == "Buzz"
# Out:
# Overwriting test_fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 4 items
#
# test_fizzbuzz.py ...F                                                    [100%]
#
# =================================== FAILURES ===================================
# ___________________________ test_retorna_Buzz_para_5 ___________________________
#
#     def test_retorna_Buzz_para_5():
# >       assert fizzbuzz(5) == "Buzz"
# E       AssertionError: assert '5' == 'Buzz'
# E
# E         - Buzz
# E         + 5
#
# test_fizzbuzz.py:8: AssertionError
# =========================== short test summary info ============================
# FAILED test_fizzbuzz.py::test_retorna_Buzz_para_5 - AssertionError: assert '5' == 'Buzz'
# ========================= 1 failed, 3 passed in 0.08s ==========================

# %% [markdown]
# *(**Resultado Esperado:** Falha. `assert '5' == 'Buzz'`)*
#
# ### 🟢 GREEN

# %%
# %%writefile fizzbuzz.py
def fizzbuzz(num):
    if num % 3 == 0:
        return "Fizz"
    if num % 5 == 0:
        return "Buzz"

    return str(num)
# Out:
# Overwriting fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 4 items
#
# test_fizzbuzz.py ....                                                    [100%]
#
# ============================== 4 passed in 0.01s ===============================

# %% [markdown]
# ## 🔄 Ciclo 5: A Regra "FizzBuzz" (O Bug)
#
# > **(O que você vai dizer):** "Nosso código parece correto, certo? Vamos ver o que o TDD acha. Vamos adicionar o teste para 15."
#
# ### 🔴 RED

# %%
# %%writefile test_fizzbuzz.py
from fizzbuzz import fizzbuzz

def test_retorna_1_para_1(): assert fizzbuzz(1) == "1"
def test_retorna_2_para_2(): assert fizzbuzz(2) == "2"
def test_retorna_Fizz_para_3(): assert fizzbuzz(3) == "Fizz"
def test_retorna_Buzz_para_5(): assert fizzbuzz(5) == "Buzz"

def test_retorna_FizzBuzz_para_15():
    assert fizzbuzz(15) == "FizzBuzz"
# Out:
# Overwriting test_fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 5 items
#
# test_fizzbuzz.py ....F                                                   [100%]
#
# =================================== FAILURES ===================================
# ________________________ test_retorna_FizzBuzz_para_15 _________________________
#
#     def test_retorna_FizzBuzz_para_15():
# >       assert fizzbuzz(15) == "FizzBuzz"
# E       AssertionError: assert 'Fizz' == 'FizzBuzz'
# E
# E         - FizzBuzz
# E         + Fizz
#
# test_fizzbuzz.py:10: AssertionError
# =========================== short test summary info ============================
# FAILED test_fizzbuzz.py::test_retorna_FizzBuzz_para_15 - AssertionError: assert 'Fizz' == 'FizzBuzz'
# ========================= 1 failed, 4 passed in 0.10s ==========================

# %% [markdown]
# *(**Resultado Esperado:** **FALHA CRÍTICA!** `assert 'Fizz' == 'FizzBuzz'`)*
#
# ### 🟢 GREEN (A Correção)
#
# > **(O que você vai dizer):** "Este é o momento crucial! O TDD acabou de pegar um bug de lógica. Nosso código retornou 'Fizz' para 15 porque a ordem estava errada. O teste nos *forçou* a corrigir a lógica, colocando o caso mais específico (FizzBuzz) primeiro."

# %%
# %%writefile fizzbuzz.py
def fizzbuzz(num):
    if num % 15 == 0:
        return "FizzBuzz"
    if num % 3 == 0:
        return "Fizz"
    if num % 5 == 0:
        return "Buzz"

    return str(num)
# Out:
# Overwriting fizzbuzz.py

# %%
# !pytest
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content
# plugins: langsmith-0.4.42, typeguard-4.4.4, anyio-4.11.0
# collected 5 items
#
# test_fizzbuzz.py .....                                                   [100%]
#
# ============================== 5 passed in 0.02s ===============================

# %% [markdown]
# ## ✅ Conclusão
#
# * Começamos com o "Fake it" (`return "1"`)
# * O segundo teste (`test_2`) nos forçou a "Make it" (`return str(num)`)
# * O TDD nos guiou passo a passo
# * Mais importante: O TDD **identificou um bug de lógica** (`test_15`) antes que ele fosse para produção.
#
# O código final e a suíte de testes são o resultado deste processo guiado.

# %%
# !cat fizzbuzz.py
# Out:
# def fizzbuzz(num):
#     if num % 15 == 0:
#         return "FizzBuzz"
#     if num % 3 == 0:
#         return "Fizz"
#     if num % 5 == 0:
#         return "Buzz"
#
#     return str(num)

# %%
# !cat test_fizzbuzz.py
# Out:
# # (testes anteriores...)
# from fizzbuzz import fizzbuzz
#
# def test_retorna_1_para_1(): assert fizzbuzz(1) == "1"
# def test_retorna_2_para_2(): assert fizzbuzz(2) == "2"
# def test_retorna_Fizz_para_3(): assert fizzbuzz(3) == "Fizz"
# def test_retorna_Buzz_para_5(): assert fizzbuzz(5) == "Buzz"
#
# def test_retorna_FizzBuzz_para_15():
#     assert fizzbuzz(15) == "FizzBuzz"
